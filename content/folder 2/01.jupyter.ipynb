# %% [markdown]
# ---
# title: 주피터 노트북
# summary: 이것은 간단한 테스트 노트북입니다.
# ---

# %% [markdown]
# 이것은 간단한 테스트 노트북입니다.

# %%
import numpy as np
import pandas as pd

print("Hello, Jupyter Notebook!")
# Out:
# Hello, Jupyter Notebook!

# %%
# 간단한 계산 예제
x = np.array([1, 2, 3, 4, 5])
y = x * 2
print(f"원본 배열: {x}")
print(f"2배한 배열: {y}")
# Out:
# 원본 배열: [1 2 3 4 5]
# 2배한 배열: [ 2  4  6  8 10]

# %% [markdown]
# ## 결과
#
# 위 코드는 NumPy를 사용하여 배열 연산을 수행합니다.
